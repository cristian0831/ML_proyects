# %% [markdown]
# # What is the fundamental idea behind Support Vector Machines?
# Set up the decision boundary that best separates classes by maximizing the margin between them.
#
# # What is a support vector
# Instances that are located on the edge of the decision boundary
#
# # Why is it important to scale the inputs when using SVMs?
# The decision boundary is dependent on the scale of input features.
